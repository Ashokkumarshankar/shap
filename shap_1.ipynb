# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
# Requirement already satisfied: numba in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (0.55.2)
# Requirement already satisfied: packaging>20.9 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (4.64.0)
# Requirement already satisfied: numpy in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (1.22.1)
# Requirement already satisfied: pandas in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (1.4.0)
# Requirement already satisfied: scikit-learn in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (1.0.2)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in c:\users\pnl0gp8t\appdata\roaming\python\python39\site-packages (from shap) (2.0.0)
# Requirement already satisfied: scipy in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from shap) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from packaging>20.9->shap) (3.0.7)
# Requirement already satisfied: colorama in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from tqdm>4.25.0->shap) (0.4.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from numba->shap) (0.38.1)
# Requirement already satisfied: setuptools in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from numba->shap) (58.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from pandas->shap) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pnl0gp8t\miniconda3\lib\site-packages (from scikit-learn->shap) (3.1.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\pnl0gp8t\miniconda3\lib\site-packages)

# %%
import shap
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
# California Housing Prices
dataset = fetch_california_housing(as_frame = True)
X = dataset['data']
y = dataset['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# Prepares a default instance of the random forest regressor
model = RandomForestRegressor()
# Fits the model on the data
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Fits the explainer
explainer = shap.Explainer(model.predict, X_test)
# Calculates the SHAP values - It takes some time
shap_values = explainer(X_test)
# Out:
# Exact explainer: 4129it [24:36,  2.78it/s]

# %%
# Evaluate SHAP values
# shap_values = explainer.shap_values(X)

# %%
shap.plots.bar(shap_values)

# %%
shap.summary_plot(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.summary_plot(shap_values, plot_type='violin')

# %%
shap.plots.bar(shap_values[0])

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.plots.force(shap_test[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 shap.plots.force(shap_test[0])
#
# NameError: name 'shap_test' is not defined
